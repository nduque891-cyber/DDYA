# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Juan Nicolas Duque Nieto" # @param {"type":"string"}
carnet = 1000114349 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
# Ejercicio: Organización de códigos de productos mediante árboles
# Una empresa necesita organizar los códigos numéricos de los productos almacenados en una bodega.
#
# Los códigos llegan en un orden aleatorio y se desea comparar el comportamiento de un Árbol Binario de Búsqueda (BST) con un Árbol AVL.
#
# Además, el sistema deberá permitir recorrer los árboles utilizando:
#
# Preorden.
#
# Inorden.
#
# Postorden.
#
# Datos de entrada
# El usuario deberá indicar cuántos códigos desea registrar.
#
# Ingrese la cantidad de productos: 8 Ingrese el código 1: 30 Ingrese el código 2: 20 Ingrese el código 3: 10 Ingrese el código 4: 25 Ingrese el código 5: 28 Ingrese el código 6: 27 Ingrese el código 7: 5 Ingrese el código 8: 50
# Los valores deberán almacenarse inicialmente en una lista:
#
# codigos = [30, 20, 10, 25, 28, 27, 5, 50]
# Punto 1. Árbol Binario de Búsqueda
# Construya un Árbol Binario de Búsqueda insertando los códigos exactamente en el orden en que fueron ingresados.
#
# Cada nodo deberá cumplir:
#
# Valores menores  <- Nodo -> Valores mayores
# El programa deberá mostrar gráficamente el árbol obtenido.
#
# No se debe reorganizar ni balancear el árbol.
#
# Punto 2. Árbol AVL
# Utilizando los mismos códigos y el mismo orden de inserción, construya ahora un Árbol AVL.
#
# Después de cada inserción se deberá calcular el factor de balance:
#
# altura(izquierda) - altura(derecha)
# Si un nodo queda desbalanceado, deberá aplicarse la rotación correspondiente:
#
# Rotación simple a la derecha Rotación simple a la izquierda Rotación doble izquierda-derecha Rotación doble derecha-izquierda
# El programa deberá mostrar gráficamente el árbol AVL final.
#
# El estudiante deberá comparar visualmente el BST con el AVL.
#
# Punto 3. Recorrido Preorden
# Realice el recorrido:
#
# Raíz -> Izquierda -> Derecha
# El programa deberá mostrar el resultado tanto para el BST como para el AVL.
#
# Punto 4. Recorrido Inorden
# Realice el recorrido:
#
# Izquierda -> Raíz -> Derecha
# El programa deberá mostrar el resultado.
#
# El estudiante deberá analizar qué característica especial tiene el recorrido inorden cuando se utiliza sobre un Árbol Binario de Búsqueda.
#
# Punto 5. Recorrido Postorden
# Realice el recorrido:
#
# Izquierda -> Derecha -> Raíz
# El programa deberá mostrar el resultado para ambos árboles.
#
# Visualización
# Los árboles deberán mostrarse de forma gráfica.
#
# Por ejemplo:
#
#         30        /  \      20    50     /  \    10   25
# No es suficiente mostrar únicamente una lista con los valores.
#
# Se puede utilizar una librería gráfica como matplotlib, networkx o cualquier otra herramienta que permita visualizar claramente:
#
# El nodo raíz.
#
# Los hijos izquierdos.
#
# Los hijos derechos.
#
# Las conexiones entre los nodos.
#
# Condiciones
# La cantidad n de elementos deberá ser indicada por el usuario.
#
# Se debe implementar manualmente la inserción del BST.
#
# Se debe implementar manualmente el balanceo del AVL.
#
# Se deben implementar los tres recorridos mediante recursividad.
#
# Los árboles deben visualizarse gráficamente.
#
# Se debe construir el BST y el AVL utilizando exactamente los mismos datos.
#
# Se debe entregar la presentación del producto en clase
#
# Se debe subir a github de forma individual y entregar el LINK DEL PR APROBADO EN ESTA TAREA DE TEAMS

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# ## Requerimientos Funcionales
#
# Permitir que el usuario inserte los productos que quiera registrar y guardar sus codigos numericos en una lista
#
#
# Armar un Árbol Binario de Búsqueda a mano poniendo los valores menores a la izquierda y los mayores a la derecha sin aplicar ningún balanceo
#
#
# Construir manualmente un Árbol AVL sacando el factor de balance tras cada inserción para aplicar las rotaciones necesarias
#
#
# Programar usando recursividad los recorridos en preorden, inorden y postorden
#
#
# Mostrar los árboles en un gráfico claro usando herramientas como networkx y matplotlib
#
# Programar toda la lógica de inserción y balanceo de los árboles
#
# Usar funciones de tipo recursivo de manera obligatoria para resolver los recorridos preorden, inorden y postorden
#
#
#
# ## Requerimientos No Funcionales
#
# Configurar la rutina de dibujo para que los colores de los nodos en el diagrama salgan de forma aleatoria
#
# Mantener el código ordenado en bloques limpios que separen la creación de los árboles, los recorridos y la parte gráfica
#
# Que el codigo este hecho en python

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
# **#1 Administrador:**
#
# Como administrador, quiero que se puedan ingresar de manera aleatoria los productos, para que el programa los organice en un arbol facil de analizar
#
# riterios de aceptacion:
#
# El programa debe permitir ingresar la cantidad de productos.
#
# El programa debe permitir ingresar el codigo de cada producto.
#
# El programa debe de organizar de manera eficiente los productos.
#
# **#2 Programador:**
#
# Como programador, quiero crear un programa que permita por medio de arboles binarios ingresar los productos de manera aleatoria para que mi cliente tenga una herramienta util de busqueda para su empresa.
#
# Criterios de aceptacion:
#
# El programa debe organizar los productos por medio de un arbol binario de busqueda (BST).
#
# El programa debe organizar los productos  por medio de un arbol AVL.
#
# El programa debe permitir ingresar los codigos de los productos y compararlos con los de los nodos siguientes.
#
# El programa debe permitir viualizar lo arboles creados.
#
# **#3 Empresario:**
#
# Como empresario, quiero tener una herramienta agil y eficiente para organizaar los producto ingresados en mi empresa.
#
# Criterios de aceptacion:
#
# El programa debe ser agil para procesar los codigos ingresados.
#
# El programa debe permitir ingresar n productos.
#
# El programa debe cumplir con las expectativas prometidas.

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5) Análisis de complejidad **[15 pts]**
# Incluye:
# - Justificación:
# Los programas de arboles tienen una complejidad variable, ya que depende de la altura del arbol.
# - Función T[n]:
# T(n)= O(h) = O(n)
# - Mejor y peor caso con gráfica
# ![{1D96FD1D-C276-437A-A435-378F416C9EEE}.png](attachment:{1D96FD1D-C276-437A-A435-378F416C9EEE}.png)

# %% [markdown]
# ## 6) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
import matplotlib.pyplot as plt



class Nodo:

    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None
        self.derecha = None
        self.altura = 1




def insertar_bst(raiz, valor):

    if raiz is None:
        return Nodo(valor)

    if valor < raiz.valor:
        raiz.izquierda = insertar_bst(raiz.izquierda, valor)


    elif valor > raiz.valor:
        raiz.derecha = insertar_bst(raiz.derecha, valor)

    return raiz


def arbol_binario(codigos):

    raiz = None

    for codigo in codigos:
        raiz = insertar_bst(raiz, codigo)

    return raiz



def altura(nodo):

    if nodo is None:
        return 0

    return nodo.altura



def factor_balance(nodo):

    if nodo is None:
        return 0

    return altura(nodo.izquierda) - altura(nodo.derecha)



def rotacion_derecha(y):

    x = y.izquierda
    t2 = x.derecha

    x.derecha = y
    y.izquierda = t2

    y.altura = 1 + max(altura(y.izquierda), altura(y.derecha))
    x.altura = 1 + max(altura(x.izquierda), altura(x.derecha))

    return x


def rotacion_izquierda(x):

    y = x.derecha
    t2 = y.izquierda

    y.izquierda = x
    x.derecha = t2

    x.altura = 1 + max(altura(x.izquierda), altura(x.derecha))
    y.altura = 1 + max(altura(y.izquierda), altura(y.derecha))

    return y


def insertar_avl(raiz, valor):

    if raiz is None:
        return Nodo(valor)

    if valor < raiz.valor:
        raiz.izquierda = insertar_avl(raiz.izquierda, valor)

    elif valor > raiz.valor:
        raiz.derecha = insertar_avl(raiz.derecha, valor)

    else:
        return raiz


    raiz.altura = 1 + max(altura(raiz.izquierda), altura(raiz.derecha))


    balance = factor_balance(raiz)

    if balance > 1 and valor < raiz.izquierda.valor:
        return rotacion_derecha(raiz)


    if balance < -1 and valor > raiz.derecha.valor:
        return rotacion_izquierda(raiz)


    if balance > 1 and valor > raiz.izquierda.valor:
        raiz.izquierda = rotacion_izquierda(raiz.izquierda)
        return rotacion_derecha(raiz)


    if balance < -1 and valor < raiz.derecha.valor:
        raiz.derecha = rotacion_derecha(raiz.derecha)
        return rotacion_izquierda(raiz)

    return raiz


# Construir el árbol AVL
def arbol_avl(codigos):

    raiz = None

    for codigo in codigos:
        raiz = insertar_avl(raiz, codigo)

    return raiz


def recorrido_preorden(raiz):

    if raiz is not None:

        print(raiz.valor, end=" ")

        recorrido_preorden(raiz.izquierda)

        recorrido_preorden(raiz.derecha)


def recorrido_inorden(raiz):

    if raiz is not None:

        recorrido_inorden(raiz.izquierda)

        print(raiz.valor, end=" ")

        recorrido_inorden(raiz.derecha)



def recorrido_postorden(raiz):

    if raiz is not None:

        recorrido_postorden(raiz.izquierda)

        recorrido_postorden(raiz.derecha)

        print(raiz.valor, end=" ")




def obtener_posiciones(nodo, x, y, espacio, posiciones, conexiones):

    if nodo is None:
        return

    posiciones[nodo] = (x, y)

    if nodo.izquierda is not None:

        conexiones.append((nodo, nodo.izquierda))

        obtener_posiciones(
            nodo.izquierda,
            x - espacio,
            y - 1,
            espacio / 2,
            posiciones,
            conexiones
        )

    if nodo.derecha is not None:

        conexiones.append((nodo, nodo.derecha))

        obtener_posiciones(
            nodo.derecha,
            x + espacio,
            y - 1,
            espacio / 2,
            posiciones,
            conexiones
        )


def visualizar(raiz, titulo):

    posiciones = {}
    conexiones = []

    obtener_posiciones(raiz, 0, 0, 8, posiciones, conexiones)

    plt.figure(figsize=(10,6))
    plt.title(titulo)


    for padre, hijo in conexiones:

        x1, y1 = posiciones[padre]
        x2, y2 = posiciones[hijo]

        plt.plot([x1, x2], [y1, y2])


    for nodo, (x, y) in posiciones.items():

        plt.scatter(x, y, s=900)

        plt.text(
            x,
            y,
            str(nodo.valor),
            ha="center",
            va="center",
            color="white",
            fontsize=10
        )

    plt.axis("off")
    plt.show()



def Main():

    cantidad = int(input("Ingrese la cantidad de productos: "))

    codigos = []

    for i in range(cantidad):

        codigo = int(input(f"Ingrese el código {i+1}: "))
        codigos.append(codigo)

    print("\nLista de códigos:")
    print(codigos)


    bst = arbol_binario(codigos)


    avl = arbol_avl(codigos)

    print("\n========== BST ==========")

    print("Preorden:")
    recorrido_preorden(bst)

    print("\n")

    print("Inorden:")
    recorrido_inorden(bst)

    print("\n")

    print("Postorden:")
    recorrido_postorden(bst)

    print("\n")

    print("========== AVL ==========")

    print("Preorden:")
    recorrido_preorden(avl)

    print("\n")

    print("Inorden:")
    recorrido_inorden(avl)

    print("\n")

    print("Postorden:")
    recorrido_postorden(avl)

    print("\n")

    visualizar(bst, "Árbol Binario de Búsqueda")

    visualizar(avl, "Árbol AVL")


Main()
# Out:
# Lista de códigos:
# [4, 8, 7, 6, 3, 2, 1, 59, 8]
#
# ========== BST ==========
# Preorden:
# 4 3 2 1 8 7 6 59
#
# Inorden:
# 1 2 3 4 6 7 8 59
#
# Postorden:
# 1 2 3 6 7 59 8 4
#
# ========== AVL ==========
# Preorden:
# 4 2 1 3 7 6 8 59
#
# Inorden:
# 1 2 3 4 6 7 8 59
#
# Postorden:
# 1 3 2 6 59 8 7 4

# %% [markdown]
# ## 7) Tests aplicados **[15 pts]**

# %%
import matplotlib.pyplot as plt



class Nodo:

    def __init__(self, valor):
        self.valor = valor
        self.izquierda = None
        self.derecha = None
        self.altura = 1




def insertar_bst(raiz, valor):

    if raiz is None:
        return Nodo(valor)

    if valor < raiz.valor:
        raiz.izquierda = insertar_bst(raiz.izquierda, valor)


    elif valor > raiz.valor:
        raiz.derecha = insertar_bst(raiz.derecha, valor)

    return raiz


def arbol_binario(codigos):

    raiz = None

    for codigo in codigos:
        raiz = insertar_bst(raiz, codigo)

    return raiz



def altura(nodo):

    if nodo is None:
        return 0

    return nodo.altura



def factor_balance(nodo):

    if nodo is None:
        return 0

    return altura(nodo.izquierda) - altura(nodo.derecha)



def rotacion_derecha(y):

    x = y.izquierda
    t2 = x.derecha

    x.derecha = y
    y.izquierda = t2

    y.altura = 1 + max(altura(y.izquierda), altura(y.derecha))
    x.altura = 1 + max(altura(x.izquierda), altura(x.derecha))

    return x


def rotacion_izquierda(x):

    y = x.derecha
    t2 = y.izquierda

    y.izquierda = x
    x.derecha = t2

    x.altura = 1 + max(altura(x.izquierda), altura(x.derecha))
    y.altura = 1 + max(altura(y.izquierda), altura(y.derecha))

    return y


def insertar_avl(raiz, valor):

    if raiz is None:
        return Nodo(valor)

    if valor < raiz.valor:
        raiz.izquierda = insertar_avl(raiz.izquierda, valor)

    elif valor > raiz.valor:
        raiz.derecha = insertar_avl(raiz.derecha, valor)

    else:
        return raiz


    raiz.altura = 1 + max(altura(raiz.izquierda), altura(raiz.derecha))


    balance = factor_balance(raiz)

    if balance > 1 and valor < raiz.izquierda.valor:
        return rotacion_derecha(raiz)


    if balance < -1 and valor > raiz.derecha.valor:
        return rotacion_izquierda(raiz)


    if balance > 1 and valor > raiz.izquierda.valor:
        raiz.izquierda = rotacion_izquierda(raiz.izquierda)
        return rotacion_derecha(raiz)


    if balance < -1 and valor < raiz.derecha.valor:
        raiz.derecha = rotacion_derecha(raiz.derecha)
        return rotacion_izquierda(raiz)

    return raiz


# Construir el árbol AVL
def arbol_avl(codigos):

    raiz = None

    for codigo in codigos:
        raiz = insertar_avl(raiz, codigo)

    return raiz


def recorrido_preorden(raiz):

    if raiz is not None:

        print(raiz.valor, end=" ")

        recorrido_preorden(raiz.izquierda)

        recorrido_preorden(raiz.derecha)


def recorrido_inorden(raiz):

    if raiz is not None:

        recorrido_inorden(raiz.izquierda)

        print(raiz.valor, end=" ")

        recorrido_inorden(raiz.derecha)



def recorrido_postorden(raiz):

    if raiz is not None:

        recorrido_postorden(raiz.izquierda)

        recorrido_postorden(raiz.derecha)

        print(raiz.valor, end=" ")




def obtener_posiciones(nodo, x, y, espacio, posiciones, conexiones):

    if nodo is None:
        return

    posiciones[nodo] = (x, y)

    if nodo.izquierda is not None:

        conexiones.append((nodo, nodo.izquierda))

        obtener_posiciones(
            nodo.izquierda,
            x - espacio,
            y - 1,
            espacio / 2,
            posiciones,
            conexiones
        )

    if nodo.derecha is not None:

        conexiones.append((nodo, nodo.derecha))

        obtener_posiciones(
            nodo.derecha,
            x + espacio,
            y - 1,
            espacio / 2,
            posiciones,
            conexiones
        )


def visualizar(raiz, titulo):

    posiciones = {}
    conexiones = []

    obtener_posiciones(raiz, 0, 0, 8, posiciones, conexiones)

    plt.figure(figsize=(10,6))
    plt.title(titulo)


    for padre, hijo in conexiones:

        x1, y1 = posiciones[padre]
        x2, y2 = posiciones[hijo]

        plt.plot([x1, x2], [y1, y2])


    for nodo, (x, y) in posiciones.items():

        plt.scatter(x, y, s=900)

        plt.text(
            x,
            y,
            str(nodo.valor),
            ha="center",
            va="center",
            color="white",
            fontsize=10
        )

    plt.axis("off")
    plt.show()



def Main():

    cantidad = int(input("Ingrese la cantidad de productos: "))

    codigos = []

    for i in range(cantidad):

        codigo = int(input(f"Ingrese el código {i+1}: "))
        codigos.append(codigo)

    print("\nLista de códigos:")
    print(codigos)


    bst = arbol_binario(codigos)


    avl = arbol_avl(codigos)

    print("\n========== BST ==========")

    print("Preorden:")
    recorrido_preorden(bst)

    print("\n")

    print("Inorden:")
    recorrido_inorden(bst)

    print("\n")

    print("Postorden:")
    recorrido_postorden(bst)

    print("\n")

    print("========== AVL ==========")

    print("Preorden:")
    recorrido_preorden(avl)

    print("\n")

    print("Inorden:")
    recorrido_inorden(avl)

    print("\n")

    print("Postorden:")
    recorrido_postorden(avl)

    print("\n")

    visualizar(bst, "Árbol Binario de Búsqueda")

    visualizar(avl, "Árbol AVL")


Main()
# Out:
# Lista de códigos:
# [15, 42, 8, 0]
#
# ========== BST ==========
# Preorden:
# 15 8 0 42
#
# Inorden:
# 0 8 15 42
#
# Postorden:
# 0 8 42 15
#
# ========== AVL ==========
# Preorden:
# 15 8 0 42
#
# Inorden:
# 0 8 15 42
#
# Postorden:
# 0 8 42 15
